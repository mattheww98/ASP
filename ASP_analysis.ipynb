# %% [markdown]
# # Analysis of ASP results

# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
with open("loss_stats.json", "r") as f:
    data = json.load(f)

# %%
train_mae = data['train']
val_mae = data['val']

# %%
l = len(train_mae)
n_epochs = 300
q = n_epochs/l
xs = np.arange(0,300,q)

# %%
plt.plot(xs,train_mae, 'o-',label=r"""$\mathrm{MAE}_\mathrm{train}$""")
plt.plot(xs,val_mae,'s--',label=r"""$\mathrm{MAE}_\mathrm{val}$""")
plt.xlabel('epochs')
plt.legend()
plt.savefig('ASP_plot.svg')

# %%
with open("val_examples.json", "r") as f:
    data = json.load(f)

# %%
print(len(data))
# Out:
# 3

# %%
print(data.keys())
# Out:
# dict_keys(['0', '19', '39'])

# %%
print(data['0'][0])
# Out:
# {'formula': 'ClO3', 'target': [0.0, 0.0, 0.0, 0.0, 4823.25, 355994.125, 332693.4375, 140217.5, 39362.3671875, 22756.1875, 20357.73828125, 33282.75, 101191.234375, 199866.375, 213441.5625, 168490.0, 212497.0, 407087.25, 178728.3125, 47425.9765625, 28315.32421875, 29507.0, 59829.7109375, 53500.05078125, 37320.34375, 59939.875, 76500.0390625, 66461.9765625, 84618.765625, 179376.0, 474662.9375, 769416.0, 996545.9375, 1097577.5, 1020224.75, 804876.75, 743238.1875, 783195.0, 765709.375, 884731.5], 'pred': [153.16357360390538, 3309.050362473968, 9737.625417878411, 18472.235914595538, 20859.224751779795, 37510.004186270206, 53943.0620444508, 60420.8142178348, 112276.92928303276, 137797.5576614918, 196721.41009164348, 194442.86298221938, 244827.130969848, 330119.6467779475, 301917.24178709014, 357967.2158946442, 416373.55850029277, 438222.79141321464, 477731.70780389255, 555527.3439549514, 496748.77016987477, 531470.6381841878, 600695.4812362577, 659646.9418232971, 702278.3392366711, 700492.0016106019, 804549.981581192, 717182.9106594482, 827776.1692456086, 891718.283779845, 909438.3543839813, 950256.8741844674, 861416.7107375758, 925521.3114103485, 949918.4403129804, 1010017.9810154982, 951038.3375474759, 1032552.7238939372, 1118397.4688082782, 1013359.303307177]}

# %%
target = data['0'][0]['target']

# %%
print(data['0'][0]['formula'], data['299'][0]['formula'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(data['0'][0]['formula'], data['299'][0]['formula'])
#
# KeyError: '299'

# %%
forms = []
for key in data:
    for i in data[key]:
        forms.append(i['formula'])

# %%
print(len(forms))
# Out:
# 144

# %%
print(144/16)
# Out:
# 9.0

# %%
i=3
e_form = data['299'][i]['formula']
e_targ = data['299'][i]['target']
e_pred = data['299'][i]['pred']

# %%
plt.plot(e_targ,label='target')
plt.plot(e_pred)
plt.legend()
